# %%
import pandas as pd

# %%
emp = ([1,'A','pune'],[2,'B','mumbai'],[3,'C','goa'])

# %%
df = pd.DataFrame(emp,columns=['id','name','city'])

# %%
df
# Out:
#    id name    city
# 0   1    A    pune
# 1   2    B  mumbai
# 2   3    C     goa

# %%
emp = ({"id":1,"name":"a","city":"pune"},
       {"id":2,"name":"b","city":"goa"})

# %%
df = pd.DataFrame(emp)

# %%
df
# Out:
#    id name  city
# 0   1    a  pune
# 1   2    b   goa

# %%
emp = {"id":(1,2,3),
       "name":('a','b','c'),
       'city':('pune','mumbai','goa')}

# %%
df = pd.DataFrame(emp)

# %%
df
# Out:
#    id name    city
# 0   1    a    pune
# 1   2    b  mumbai
# 2   3    c     goa
